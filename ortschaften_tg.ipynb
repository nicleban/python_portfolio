# %% [markdown]
# ## Ortschaten aus dem Thurgau

# %%
import json

with open('ortschafts_verzeichnis.json','r') as xyz:
    Liste=json.load(xyz)

print(Liste)
# Out:
# [{'politische_gemeinde': 'Aadorf', 'bfs_nr_gemeinde': '4551', 'bezirk_name': 'Münchwilen', 'bezirk_nr': '2014', 'ortschaft': 'Ettenhausen', 'einwohner_total': '1427', 'einwohner_maenner': '720', 'einwohner_frauen': '707', 'einwohner_0_19': '299', 'einwohner_20_39': '317', 'einwohner_40_64': '537', 'einwohner_65plus': '274', 'einwohner_schweizer': '1281', 'einwohner_auslaender_total': '146', 'einwohner_auslaender_deutsche': '51', 'einwohner_evang': '437', 'einwohner_kath': '480', 'einwohner_uebrige': '510'}, {'politische_gemeinde': 'Aadorf', 'bfs_nr_gemeinde': '4551', 'bezirk_name': 'Münchwilen', 'bezirk_nr': '2014', 'ortschaft': 'Guntershausen b. Aadorf', 'einwohner_total': '1493', 'einwohner_maenner': '765', 'einwohner_frauen': '728', 'einwohner_0_19': '304', 'einwohner_20_39': '306', 'einwohner_40_64': '592', 'einwohner_65plus': '291', 'einwohner_schweizer': '1329', 'einwohner_auslaender_total': '164', 'einwohner_auslaender_deutsche': '56', 'einwohner_evang': '457', 'einwohner_kath
# ...

# %% [markdown]
# Datensatz Runterladen

# %%
import json

with open('ortschafts_verzeichnis.json','r') as xyz:
    Liste=json.load(xyz)

for i in Liste:
    if i["ortschaft"]=="Egnach":
        print(i)
# Out:
# {'politische_gemeinde': 'Egnach', 'bfs_nr_gemeinde': '4411', 'bezirk_name': 'Arbon', 'bezirk_nr': '2011', 'ortschaft': 'Egnach', 'einwohner_total': '2127', 'einwohner_maenner': '1076', 'einwohner_frauen': '1051', 'einwohner_0_19': '476', 'einwohner_20_39': '489', 'einwohner_40_64': '787', 'einwohner_65plus': '375', 'einwohner_schweizer': '1756', 'einwohner_auslaender_total': '371', 'einwohner_auslaender_deutsche': '110', 'einwohner_evang': '775', 'einwohner_kath': '596', 'einwohner_uebrige': '756'}
# {'politische_gemeinde': 'Salmsach', 'bfs_nr_gemeinde': '4441', 'bezirk_name': 'Arbon', 'bezirk_nr': '2011', 'ortschaft': 'Egnach', 'einwohner_total': 'x', 'einwohner_maenner': 'x', 'einwohner_frauen': 'x', 'einwohner_0_19': 'x', 'einwohner_20_39': 'x', 'einwohner_40_64': 'x', 'einwohner_65plus': 'x', 'einwohner_schweizer': 'x', 'einwohner_auslaender_total': 'x', 'einwohner_auslaender_deutsche': 'x', 'einwohner_evang': 'x', 'einwohner_kath': 'x', 'einwohner_uebrige': 'x'}

# %% [markdown]
# Meine Gemeinde
# Achtung Gemeinden GROSSSCHREIBEN

# %%
import json

with open('data/ortschafts_verzeichnis.json','r') as xyz:
    Liste=json.load(xyz)

    print(f'|{'Name der Ortschaft':<20}|{'Einwohner':<20}|')
    print(f'|{'':>20}|{'':>20}|')
for i in Liste:
    print(f'|{i['bezirk_name']:<20}|{i['einwohner_total']:<20}|')
# Out:
# |Name der Ortschaft  |Einwohner           |
# |                    |                    |
# |Münchwilen          |1427                |
# |Münchwilen          |1493                |
# |Weinfelden          |x                   |
# |Arbon               |130                 |
# |Arbon               |996                 |
# |Arbon               |1324                |
# |Weinfelden          |210                 |
# |Weinfelden          |107                 |
# |Weinfelden          |506                 |
# |Münchwilen          |1273                |
# |Münchwilen          |1995                |
# |Weinfelden          |59                  |
# |Weinfelden          |177                 |
# |Weinfelden          |36                  |
# |Weinfelden          |102                 |
# |Weinfelden          |x                   |
# |Weinfelden          |115                 |
# |Weinfelden          |154                 |
# |Weinfelden          |107                 |
# ...

# %% [markdown]
# Schöne Tabelle mit Ortschaften und Einwohnern

# %%
import json

with open('data/ortschafts_verzeichnis.json','r') as xyz:
    Liste=json.load(xyz)

    print(f'|{'Name der Ortschaft':<20}|{'Einwohner':<20}|')
    print(f'|{'':>20}|{'':>20}|')
for i in Liste:
    if i>a:
        
    a=i
